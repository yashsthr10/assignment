# %%
from IPython.display import Image

# %%
print('The given plot suggests that people are more towards the premium products than the other two')
Image(filename="images/LS-PC-Dictribution.png")
# Out:
# The given plot suggests that people are more towards the premium products than the other two

# %%
print('the older people the equally buying in all the three price brackets')
Image(filename="images/LSvsPC.png")
# Out:
# the older people the equally buying in all the three price brackets

# %%
print('these are the most selling products')
Image(filename="images/top-products.png")
# Out:
# these are the most selling products

# %%
print('these are the Most Loyal Customers')
Image(filename="images/loyalCustomers.png")
# Out:
# these are the Most Loyal Customers

# %%
print("the given chart suggest that the older and youger families are spending the most")
Image(filename="images/LSvsAvgSpndg.png")
# Out:
# the given chart suggest that the older and youger families are spending the most

# %%
##### MY HYPOTHESIS #######
"""loyal people likes because -"""

# 1. Taste & Flavor Preferences
# 2. Brand Loyalty & Trust
# 3. Older people are more stable and used to the same product
# 4. Convenience & Availability is also a factor to it 



#--------Summary---------#
"""
Project: Customer Loyalty Analysis

Objective:
Analyze loyal customers' purchasing behavior and find the most preferred products.

Key Insights:
- Loyal customers prefer premium brands.
- Bulk purchases are common among families.
- Discount-driven purchases suggest price sensitivity.

Results:
- **Top product:** Dorito Corn Chip Supreme 380g
- **Spending trend:** mainstream customers buys more frequently.
- **Lifestage impact:** Older Families buys premium products in bulk , youngs are more frequent but non-premium buyers.

Recommendations:
- Targeted marketing for premium snack buyers.
- Offer bulk discounts for family-oriented customers.
"""
# Out:
# "\nProject: Customer Loyalty Analysis\n\nObjective:\nAnalyze loyal customers' purchasing behavior and find the most preferred products.\n\nKey Insights:\n- Loyal customers prefer premium brands.\n- Bulk purchases are common among families.\n- Discount-driven purchases suggest price sensitivity.\n\nResults:\n- **Top product:** Dorito Corn Chip Supreme 380g\n- **Spending trend:** mainstream customers buys more frequently.\n- **Lifestage impact:** Older Families buys premium products in bulk , youngs are more frequent but non-premium buyers.\n\nRecommendations:\n- Targeted marketing for premium snack buyers.\n- Offer bulk discounts for family-oriented customers.\n"
